# %% [markdown]
# Trying to make a Cube class that can hold 6 colors, four will be visible which are front back left and right and two will be hidden at the top and bottom.
#
# We should be able to spin the cube from eagles eye point of view making front left, left back, back right, and right front.
#
# Rotate the cube clockwise from the frontal view making hidden top right, right hidden bottom, hidden bottom left, and left hidden top.

# %%
import random

class InstantInsanity:
    def __init__(self, numOfCubes, numOfColors):
        self.size = 0
        self.cubes = []
        self.numOfCubes = numOfCubes
        self.numOfColors = numOfColors
        self.addCubes()
    
    def addCube(self):
        colors = [random.randint(0,self.numOfColors) for i in range(6)]
        self.cubes.append(Cube(colors[0], colors[1], colors[2], colors[3], colors[4], colors[5]))
        self.size += 1
        
    # I'm not sure why I would want to remove a cube but I thought about it
    # maybe removing it could lead to a solution or half solution
    def removeCube(self):
        
        self.size -= 1
        
    def getSize(self):
        return self.size
    
    def addCubes(self):
        for i in range(self.numOfCubes):
            self.addCube()    
    
    def showCubes(self):
        for i in range(self.size):
            self.cubes[i].outputSides()
            
    def solve():
        print("this will try to solve the game")
        
        #Not needed just a visual aid to see double face pairings
    def breakDown():
        for i in range(self.size):
            if(self.front == self.back):
                print()
            elif(self.left == self.right):
                print()
            elif(self.top == self.bottom):
                print()

# %% [markdown]
# The following contains methods that modify and move the cube around

# %%
class Cube:
    # initialize cube sides to colors/integers you want
    def __init__(self, c0, c1, c2, c3, c4, c5):
        self.front = c0
        self.back = c1
        self.left = c2
        self.right = c3
        self.top = c4
        self.bottom = c5

    def spinCW(self):
        temp = self.left
        self.left = self.front
        self.front = self.right
        self.right = self.back
        self.back = temp        

    # spin front left back right clockwise like a dreidel    
    def spinCCW(self):
        temp = self.front
        self.front = self.left
        self.left = self.back
        self.back = self.right
        self.right = temp

    # rotate the top right bottom and left clockwise
    def rotateCW(self):
        temp = self.top
        self.top = self.left
        self.left = self.bottom
        self.bottom = self.right
        self.right = temp

    def rotateCCW(self):
        temp = self.top
        self.top = self.right
        self.right = self.bottom
        self.bottom = self.left
        self.left = temp

    # this should allow you to switch orientation of pairs    
    def switchPair(self, pair):
        if pair == 0:
            temp = self.front
            self.front = self.back
            self.back = temp
        elif pair == 1:
            temp = self.right
            self.right = self.left
            self.left = temp
        elif pair == 2:
            temp = self.top
            self.top = self.bottom
            self.bottom = temp
        else:
            print("There are only 3 pairs labeled 0-2")

    def outputSides(self):
        print(self.front, self.back, self.left, self.right, self.top, self.bottom)

# %%
game = InstantInsanity(26,50)
game.showCubes()
#game.cubes[2].switchPair(2)
print(game.getSize())
# Out:
# 19 46 37 31 25 1
# 45 4 3 35 10 32
# 45 7 36 42 41 34
# 48 45 28 12 35 18
# 40 50 9 15 14 21
# 29 38 41 13 33 35
# 44 35 20 44 17 44
# 24 36 27 12 14 33
# 7 34 19 15 23 46
# 4 38 31 45 50 49
# 46 29 43 44 48 32
# 19 17 14 31 26 34
# 13 46 36 42 28 36
# 36 30 21 6 31 44
# 8 12 21 35 26 30
# 26 1 20 4 5 0
# 29 49 38 31 37 20
# 3 4 24 9 48 2
# 42 24 41 30 30 0
# 41 48 41 24 43 9
# 24 18 31 21 21 34
# 8 7 20 0 48 4
# 23 11 37 37 0 16
# 48 47 24 37 45 7
# 6 17 7 2 21 11
# 40 38 21 20 8 37
# 26

# %%
print("front", "back", "left", "right", "top", "bottom")
print()

cube1 = InstantInsanity.Cube(0,1,2,3,4,5)

print("Testing clockwise cube spins\n")

cube1.outputSides()

cube1.spinCW()
cube1.outputSides()

cube1.spinCW()
cube1.outputSides()

cube1.spinCW()
cube1.outputSides()

cube1.spinCW()
cube1.outputSides()

print("\nTesting counterclockwise cube spins\n")

cube1.outputSides()

cube1.spinCCW()
cube1.outputSides()

cube1.spinCCW()
cube1.outputSides()

cube1.spinCCW()
cube1.outputSides()

cube1.spinCCW()
cube1.outputSides()

print("\nTesting clockwise cube rotations\n")

cube1.outputSides()

cube1.rotateCW()
cube1.outputSides()

cube1.rotateCW()
cube1.outputSides()

cube1.rotateCW()
cube1.outputSides()

cube1.rotateCW()
cube1.outputSides()

print("\nTesting counterclockwise cube rotations\n")

cube1.outputSides()

cube1.rotateCCW()
cube1.outputSides()

cube1.rotateCCW()
cube1.outputSides()

cube1.rotateCCW()
cube1.outputSides()

cube1.rotateCCW()
cube1.outputSides()

print("\nTesting Pair Switching\n")

cube1.outputSides()

cube1.switchPair(0)
cube1.outputSides()

cube1.switchPair(0)
cube1.outputSides()

cube1.switchPair(1)
cube1.outputSides()

cube1.switchPair(1)
cube1.outputSides()

cube1.switchPair(2)
cube1.outputSides()

cube1.switchPair(2)
cube1.outputSides()
# Out:
# front back left right top bottom
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3c7ee40c2fe4> in <module>()
#       2 print()
#       3
# ----> 4 cube1 = InstantInsanity.Cube(0,1,2,3,4,5)
#       5
#       6 print("Testing clockwise cube spins\n")
#
# AttributeError: type object 'InstantInsanity' has no attribute 'Cube'

# %% [markdown]
# When the object to hold the cubes is created we will need the following methods:
# 1. A method to go through each side of the stack of cubes and check if there are no repeats
# 2.
